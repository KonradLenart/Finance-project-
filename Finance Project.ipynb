# %% [markdown]
# # Finance Data Project
#
# In this data project we will focus on exploratory data analysis of stock prices.

# %%
from pandas_datareader import data, wb
import seaborn as sns
import pandas as pd
import numpy as np
import datetime
# %matplotlib inline

# %% [markdown]
# ## Data
#
# We need to get data using pandas datareader. We will get stock information for the following banks:
# *  Bank of America
# * CitiGroup
# * Goldman Sachs
# * JPMorgan Chase
# * Morgan Stanley
# * Wells Fargo

# %%
# Bank of America
BAC =data.DataReader('BAC',start='2006', end='2019',data_source='yahoo')

# CitiGroup
C =data.DataReader('C',start='2006', end='2019',data_source='yahoo')

# Goldman Sachs
GS =data.DataReader('GS',start='2006', end='2019',data_source='yahoo')

# JPMorgan Chase
JPM =data.DataReader('JPM',start='2006', end='2019',data_source='yahoo')

# Morgan Stanley
MS =data.DataReader('MS',start='2006', end='2019',data_source='yahoo')

# Wells Fargo
WFC =data.DataReader('WFC',start='2006', end='2019',data_source='yahoo')

# %%
GS
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2006-01-03  129.440002  124.230003  126.699997  128.869995  6188700.0
# 2006-01-04  128.910004  126.379997  127.349998  127.089996  4861600.0
# 2006-01-05  127.320000  125.610001  126.000000  127.040001  3717400.0
# 2006-01-06  129.250000  127.290001  127.290001  128.839996  4319600.0
# 2006-01-09  130.619995  128.000000  128.500000  130.389999  4723500.0
# 2006-01-10  132.949997  130.020004  130.050003  132.029999  5536800.0
# 2006-01-11  133.800003  131.419998  131.449997  131.970001  4671400.0
# 2006-01-12  133.210007  131.380005  131.399994  132.250000  3725500.0
# 2006-01-13  133.660004  131.899994  132.020004  133.259995  2894900.0
# 2006-01-17  133.130005  130.589996  131.000000  132.589996  3621600.0
# 2006-01-18  132.679993  131.009995  131.059998  132.369995  4302700.0
# 2006-01-19  134.820007  132.710007  132.720001  133.820007  5010700.0
# ...

# %% [markdown]
# # Creating a list of the ticker symbols (as strings) in alphabetical order.

# %%
tickers = ['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC']

# %% [markdown]
# # Usage pd.contact to concatenate the bank dataframes together with a single data frame called bank_stocks

# %%
bank_stocks = pd.concat([BAC, C, GS, JPM, MS, WFC],axis=1,keys=tickers)

# %% [markdown]
# # Seting the column name levels

# %%
bank_stocks.columns.names = ['Bank Ticker','Stock Info']

# %%
bank_stocks.head()
# Out:
# Bank Ticker        BAC                                               \
# Stock Info        High        Low       Open      Close      Volume
# Date
# 2006-01-03   47.180000  46.150002  46.919998  47.080002  16296700.0
# 2006-01-04   47.240002  46.450001  47.000000  46.580002  17757900.0
# 2006-01-05   46.830002  46.320000  46.580002  46.639999  14970700.0
# 2006-01-06   46.910000  46.349998  46.799999  46.570000  12599800.0
# 2006-01-09   46.970001  46.360001  46.720001  46.599998  15619400.0
#
# Bank Ticker                      C                                      \
# Stock Info   Adj Close        High         Low        Open       Close
# Date
# 2006-01-03   35.953278  493.799988  481.100006  490.000000  492.899994
# 2006-01-04   35.571438  491.000000  483.500000  488.600006  483.799988
# 2006-01-05   35.617275  487.799988  484.000000  484.399994  486.200012
# 2006-01-06   35.563797  489.000000  482.000000  488.799988  486.200012
# ...

# %% [markdown]
# # EDA
#
# Let's explore the data a bit!
#
# What is the max Close price for each bank's stock throughout the time period?

# %%
bank_stocks.xs(key='Close',axis=1,level='Stock Info').max()
# Out:
# Bank Ticker
# BAC     54.900002
# C      564.099976
# GS     273.380005
# JPM    118.769997
# MS      89.300003
# WFC     65.930000
# dtype: float64

# %% [markdown]
# This dataframe will contain the returns for each bank's stock. Returns are typically defined by:
#
# $$r_t = \frac{p_t - p_{t-1}}{p_{t-1}} = \frac{p_t}{p_{t-1}} - 1$$

# %%
returns = pd.DataFrame()

# %%
for tick in tickers:
    returns[tick+' Return'] = bank_stocks[tick]['Close'].pct_change()
returns.head()
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.014183   0.000686   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.001110
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.001025    0.005874
# 2006-01-09    0.000644 -0.004731   0.012030    0.016242   0.010586   -0.000158

# %% [markdown]
# # Creating a pairplot using seaborn of the returns dataframe.

# %%
sns.pairplot(data=returns[1:])

# %% [markdown]
# # Using this returns DataFrame, We can figure out on what dates each bank stock had the best and worst single day returns.

# %%
returns.idxmin()
# Out:
# BAC Return   2009-01-20
# C Return     2009-02-27
# GS Return    2009-01-20
# JPM Return   2009-01-20
# MS Return    2008-10-09
# WFC Return   2009-01-20
# dtype: datetime64[ns]

# %% [markdown]
# As we can see the biggest drawdown 4 of the company recorded on January 20, 2009 was due to you from that day Barack Obama was inaugurated as the 44th President of the United States of America

# %%
returns.idxmax()
# Out:
# BAC Return   2009-04-09
# C Return     2008-11-24
# GS Return    2008-11-24
# JPM Return   2009-01-21
# MS Return    2008-10-13
# WFC Return   2008-07-16
# dtype: datetime64[ns]

# %% [markdown]
# As we can see, two of the dates are repeated. On November 24, 2008, Citigroup gets massive government bailout.Shares of Citigroup rose 58 percent on Monday.

# %% [markdown]
# # standard deviation for companies throughout the analysis period

# %%
returns.std()
# Out:
# BAC Return    0.033128
# C Return      0.034764
# GS Return     0.023453
# JPM Return    0.025108
# MS Return     0.034189
# WFC Return    0.027339
# dtype: float64

# %% [markdown]
# # standard deviation for companies in 2015

# %%
returns.loc['2015-01-01':'2015-12-31'].std()
# Out:
# BAC Return    0.016163
# C Return      0.015289
# GS Return     0.014046
# JPM Return    0.014017
# MS Return     0.016249
# WFC Return    0.012591
# dtype: float64

# %% [markdown]
# # As we see, CitiGroup was the most risky investment in the entire analysis period, and in 2015 Morgan Stanley was the most risky investment

# %% [markdown]
# # distplot: using seaborn of the 2015 returns for Morgan Stanley

# %%
sns.distplot(returns.loc['2015-01-01':'2015-12-31']['MS Return'],color='green',bins=100)

# %% [markdown]
# # distplot: using seaborn of the 2008 returns for CitiGroup

# %%
sns.distplot(returns.loc['2008-01-01':'2008-12-31']['C Return'],color='red',bins=100)

# %% [markdown]
# #  More Visualization
# Imports

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# Optional Plotly Method Imports
import plotly
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Line plot showing Close price for each bank for the entire index of time.

# %%
for tick in tickers:
    bank_stocks[tick]['Close'].plot(figsize=(12,4),label=tick)
plt.legend()

# %%
for tick in tickers:
    bank_stocks[tick]['Close'].plot(figsize=(12,4),label=tick)
plt.legend()

# %% [markdown]
# ## Moving Averages
#
# Let's analyze the moving averages for these stocks in the year 2008.
#
# ** Plot the rolling 30 day average against the Close Price for Bank Of America's stock for the year 2008**

# %%
plt.figure(figsize=(12,6))
BAC['Close'].loc['2008-01-01':'2009-01-01'].rolling(window=30).mean().plot(label='30 Day Avg')
BAC['Close'].loc['2008-01-01':'2009-01-01'].plot(label='BAC CLOSE')
plt.legend()

# %% [markdown]
# # Correlation between the stocks Close Price.

# %%
sns.heatmap(bank_stocks.xs(key='Close',axis=1,level='Stock Info').corr(),annot=True)

# %% [markdown]
# # Use of seaborn's clustermap to cluster the correlations together

# %%
sns.clustermap(bank_stocks.xs(key='Close',axis=1,level='Stock Info').corr(),annot=True)

# %% [markdown]
# # Usage of .iplot(kind='candle) to create a candle plot of Bank of America's stock from Jan 1st 2015 to Jan 1st 2016.

# %%
BAC[['Open', 'High', 'Low', 'Close']].loc['2015-01-01':'2016-01-01'].iplot(kind='candle')
# Out:
# <div>
#
#
#             <div id="4b68ba55-0598-4175-b521-4779c6406a33" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("4b68ba55-0598-4175-b521-4779c6406a33")) {
#                     Plotly.newPlot(
#                         '4b68ba55-0598-4175-b521-4779c6406a33',
# ...

# %% [markdown]
# # Usage .ta_plot(study='sma') to create a Simple Moving Averages plot of Morgan Stanley for the year 2015.

# %%
MS['Close'].loc['2015-01-01':'2016-01-01'].ta_plot(study='sma',periods=[13,21,55],title='Simple Moving Averages')
# Out:
# <div>
#
#
#             <div id="90078813-4f32-407c-9bfe-a39e307eabc7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("90078813-4f32-407c-9bfe-a39e307eabc7")) {
#                     Plotly.newPlot(
#                         '90078813-4f32-407c-9bfe-a39e307eabc7',
# ...

# %% [markdown]
# # Usage of .ta_plot(study='boll') to create a Bollinger Band Plot for Bank of America for the year 2015.

# %%
BAC['Close'].loc['2015-01-01':'2016-01-01'].ta_plot(study='boll')
# Out:
# <div>
#
#
#             <div id="f72ac3d0-9912-4015-be0d-4f77c6e6e13f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("f72ac3d0-9912-4015-be0d-4f77c6e6e13f")) {
#                     Plotly.newPlot(
#                         'f72ac3d0-9912-4015-be0d-4f77c6e6e13f',
# ...
